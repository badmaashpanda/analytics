# %% [markdown]
# # Assumptions of Linear Regression

# %% [markdown]
# Linear Regression cannot be applied to all data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Linearity:
